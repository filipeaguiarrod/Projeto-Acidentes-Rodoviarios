# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import streamlit as st
from geopy.geocoders import Nominatim

# %%
user_input = input("Localização do acidente")
# Out:
# Localização do acidente Rua Francisco Hurtado

# %%
geolocator = Nominatim(user_agent="Acidente")
location = geolocator.geocode(user_input)

# %%
print(location.latitude, location.longitude)
# Out:
# -23.6325412 -46.6227272

# %%
BBox = ((df.longitude.min(),   df.longitude.max(),      
         df.latitude.min(), df.latitude.max())

# %%
BBox = ((-33.943,4.828,      
         -74.092, -34.893))

# %%
ruh_m = plt.imread('Brasil.png')

# %%
fig, ax = plt.subplots(figsize = (12.5,12.5))
ax.scatter(location.longitude, location.latitude, zorder=1, alpha= 0.2, c='b', s=10)
ax.set_title('Localização Acidente')
ax.set_xlim(BBox[0],BBox[1])
ax.set_ylim(BBox[2],BBox[3])
ax.imshow(ruh_m, zorder=0, extent = BBox, aspect= 'equal')

# %%
user_input_2 = input('Escreva aqui qual hora')
# Out:
# Escreva aqui qual hora 10:55

# %%
user_input_2.split()

# Trabalhar na transformação para float:!!!!!!!!!

list_h = horario.split(':') # Cria lista com Hora, Minuto
hor_flt = float(list_h[0]) + float(list_h[1])/60 # Transforma hora e minuto em um float
horario_sin=np.sin(2.*np.pi*hor_flt/24.) # Transforma o horário em sin.

print(horario_sin)
# Out:
# 0.4226182617406995

# %%
horario = '10:20'

# %%
list_h = horario.split(':')

# %%
hor_flt = float(list_h[0]) + float(list_h[1])/60

# %%
hor_flt
# Out:
# 10.333333333333334

# %%
horario_sin=np.sin(2.*np.pi*hor_flt/24.)

# %%
horario_sin
# Out:
# 0.4226182617406995

# %%
df_testando = pd.DataFrame({'horario_sin':[0.3827],'latitude':[-23.6325],'longitude':[-46.6227]})

# %%
df
# Out:
#    horario_sin  latitude  longitude
# 0       0.3827  -23.6325   -46.6227

# %%
import pickle

# %%
loaded_model = pickle.load(open('finalized_model.sav', 'rb'))
result = loaded_model.predict(df)

# %%
result
# Out:
# array(['Com Vítimas Feridas'], dtype=object)
